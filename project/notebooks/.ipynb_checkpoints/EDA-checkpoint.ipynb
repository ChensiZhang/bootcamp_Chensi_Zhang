# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt, seaborn as sns
from scipy.stats import skew, kurtosis

# %%
data = pd.read_csv('C:/Users/Zhangchensi/bootcamp_Chensi_Zhang/project/data/processed/processed_data.csv')
data = data.iloc[:,1:]
data
# Out:
#           open      high       low     close    volume  year
# 0     0.050354  0.046686  0.043518  0.045676  0.130251  2015
# 1     0.043057  0.040097  0.038797  0.038268  0.164745  2015
# 2     0.038937  0.037216  0.036898  0.038292  0.169450  2015
# 3     0.040491  0.039035  0.041924  0.041876  0.089477  2015
# 4     0.045269  0.048362  0.046804  0.051834  0.149426  2015
# ...        ...       ...       ...       ...       ...   ...
# 2668  0.332094  0.338466  0.343085  0.343933  0.182155  2025
# 2669  0.339121  0.338749  0.344107  0.342610  0.126241  2025
# 2670  0.338991  0.336765  0.340420  0.339747  0.139073  2025
# 2671  0.333577  0.334026  0.342306  0.338064  0.081290  2025
# 2672  0.332576  0.333436  0.340457  0.337270  0.087287  2025
#
# [2673 rows x 6 columns]

# %%
data.info
# Out:
# <bound method DataFrame.info of           open      high       low     close    volume  year
# 0     0.050354  0.046686  0.043518  0.045676  0.130251  2015
# 1     0.043057  0.040097  0.038797  0.038268  0.164745  2015
# 2     0.038937  0.037216  0.036898  0.038292  0.169450  2015
# 3     0.040491  0.039035  0.041924  0.041876  0.089477  2015
# 4     0.045269  0.048362  0.046804  0.051834  0.149426  2015
# ...        ...       ...       ...       ...       ...   ...
# 2668  0.332094  0.338466  0.343085  0.343933  0.182155  2025
# 2669  0.339121  0.338749  0.344107  0.342610  0.126241  2025
# 2670  0.338991  0.336765  0.340420  0.339747  0.139073  2025
# 2671  0.333577  0.334026  0.342306  0.338064  0.081290  2025
# 2672  0.332576  0.333436  0.340457  0.337270  0.087287  2025
#
# [2673 rows x 6 columns]>

# %%
desc = data[['open','high','low','close','volume']].describe().T
desc['skew'] = [skew(data[c].dropna()) for c in desc.index]
desc['kurtosis'] = [kurtosis(data[c].dropna()) for c in desc.index]
desc
# Out:
#          count      mean       std  min       25%       50%       75%  max  \
# open    2673.0  0.196192  0.138802  0.0  0.094329  0.177617  0.255844  1.0
# high    2673.0  0.197231  0.141142  0.0  0.093498  0.178761  0.257256  1.0
# low     2673.0  0.199988  0.141963  0.0  0.095629  0.181583  0.261719  1.0
# close   2673.0  0.200047  0.142319  0.0  0.095755  0.180734  0.261094  1.0
# volume  2673.0  0.135421  0.105573  0.0  0.060301  0.109716  0.181665  1.0
#
#             skew  kurtosis
# open    1.741185  5.009286
# high    1.746126  5.000908
# low     1.725502  4.910930
# close   1.741339  4.981645
# volume  1.985394  7.045678

# %%
sns.histplot(data['open'], kde=True)
plt.title('open Distribution')
plt.show()

# %%
sns.histplot(data['close'], kde=True)
plt.title('close Distribution')
plt.show()

# %%
sns.histplot(data['high'], kde=True)
plt.title('high Distribution')
plt.show()

# %%
sns.histplot(data['low'], kde=True)
plt.title('low Distribution')
plt.show()

# %%
sns.boxplot(x=data['volume'])
plt.title('low (Outliers)')
plt.show()

# %%
sns.scatterplot(data=data, x='open', y='close', hue='year')
plt.title('open vs close')
plt.show()

# %%
sns.scatterplot(data=data, x='high', y='low')
plt.title('high vs low')
plt.show()
