# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import train_test_split
import scipy.stats as st
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout

sns.set()
np.random.seed(7)

# %%
df = pd.read_csv('C:/Users/Zhangchensi/bootcamp_Chensi_Zhang/project/data/processed/processed_data.csv')
df = df.set_index(df.columns[0])
df.index.name = None
df
# Out:
#                 open      high       low     close    volume  year
# 2015-01-02  0.050354  0.046686  0.043518  0.045676  0.130251  2015
# 2015-01-05  0.043057  0.040097  0.038797  0.038268  0.164745  2015
# 2015-01-06  0.038937  0.037216  0.036898  0.038292  0.169450  2015
# 2015-01-07  0.040491  0.039035  0.041924  0.041876  0.089477  2015
# 2015-01-08  0.045269  0.048362  0.046804  0.051834  0.149426  2015
# ...              ...       ...       ...       ...       ...   ...
# 2025-08-13  0.332094  0.338466  0.343085  0.343933  0.182155  2025
# 2025-08-14  0.339121  0.338749  0.344107  0.342610  0.126241  2025
# 2025-08-15  0.338991  0.336765  0.340420  0.339747  0.139073  2025
# 2025-08-18  0.333577  0.334026  0.342306  0.338064  0.081290  2025
# 2025-08-19  0.332576  0.333436  0.340457  0.337270  0.087287  2025
#
# [2673 rows x 6 columns]

# %%
features = ['open', 'high', 'low', 'close', 'volume']
target = 'close'
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df[features])
df_scaled = pd.DataFrame(df_scaled, columns=features, index=df.index)

time_steps = 3
X, y = [], []
for i in range(time_steps, len(df_scaled)):
    X.append(df_scaled.iloc[i-time_steps:i][features].values)
    y.append(df_scaled.iloc[i][target]) 
X = np.array(X)
y = np.array(y)

split_ratio = 0.8
split_index = int(len(X) * split_ratio)
X_train, X_test = X[:split_index], X[split_index:]
y_train, y_test = y[:split_index], y[split_index:]

model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dropout(0.2))
model.add(LSTM(50, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mse')

history = model.fit(X_train, y_train, epochs=50, batch_size=32, 
                    validation_data=(X_test, y_test), verbose=1, shuffle=False)

y_pred = model.predict(X_test)

close_scaler = StandardScaler()
close_scaler.fit(df[['close']]) 

y_test_orig = close_scaler.inverse_transform(y_test.reshape(-1, 1))
y_pred_orig = close_scaler.inverse_transform(y_pred)

rmse = np.sqrt(mean_squared_error(y_test_orig, y_pred_orig))
print(f"Test RMSE: {rmse}")

import matplotlib.pyplot as plt
plt.plot(y_test_orig, label='True')
plt.plot(y_pred_orig, label='Predicted')
plt.legend()
plt.show()
# Out:
# E:\anaconda\envs\bootcamp_env\lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - loss: 0.4548 - val_loss: 0.2984
# Epoch 2/50
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.1273 - val_loss: 0.2674
# Epoch 3/50
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0972 - val_loss: 0.0738
# Epoch 4/50
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0734 - val_loss: 0.0173
# Epoch 5/50
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0715 - val_loss: 0.0150
# Epoch 6/50
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0615 - val_loss: 0.0115
# Epoch 7/50
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0536 - val_loss: 0.0099
# Epoch 8/50
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0448 - val_loss: 0.0093
# Epoch 9/50
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0429 - val_loss: 0.0092
# Epoch 10/50
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0434 - val_loss: 0.0149
# Epoch 11/50
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0401 - val_loss: 0.0285
# Epoch 12/50
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0384 - val_loss: 0.0336
# Epoch 13/50
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0517 - val_loss: 0.0143
# Epoch 14/50
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0454 - val_loss: 0.0665
# Epoch 15/50
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0560 - val_loss: 0.0209
# Epoch 16/50
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 0.0430 - val_loss: 0.0187
# Epoch 17/50
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0496 - val_loss: 0.0154
# Epoch 18/50
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0435 - val_loss: 0.0642
# Epoch 19/50
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0435 - val_loss: 0.0191
# Epoch 20/50
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0404 - val_loss: 0.0267
# Epoch 21/50
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0401 - val_loss: 0.0092
# Epoch 22/50
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.0442 - val_loss: 0.0342
# Epoch 23/50
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0439 - val_loss: 0.0123
# Epoch 24/50
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0384 - val_loss: 0.2108
# Epoch 25/50
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0537 - val_loss: 0.0176
# Epoch 26/50
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0507 - val_loss: 0.0349
# Epoch 27/50
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0386 - val_loss: 0.0074
# Epoch 28/50
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0339 - val_loss: 0.0066
# Epoch 29/50
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0411 - val_loss: 0.0133
# Epoch 30/50
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0332 - val_loss: 0.0070
# Epoch 31/50
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0334 - val_loss: 0.1089
# Epoch 32/50
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0523 - val_loss: 0.0212
# Epoch 33/50
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0360 - val_loss: 0.0130
# Epoch 34/50
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0323 - val_loss: 0.0111
# Epoch 35/50
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0348 - val_loss: 0.0072
# Epoch 36/50
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0295 - val_loss: 0.0080
# Epoch 37/50
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0308 - val_loss: 0.0062
# Epoch 38/50
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0280 - val_loss: 0.0095
# Epoch 39/50
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0332 - val_loss: 0.0177
# Epoch 40/50
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0344 - val_loss: 0.0133
# Epoch 41/50
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0346 - val_loss: 0.0800
# Epoch 42/50
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0404 - val_loss: 0.0119
# Epoch 43/50
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0461 - val_loss: 0.0084
# Epoch 44/50
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0395 - val_loss: 0.0072
# Epoch 45/50
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0366 - val_loss: 0.0417
# Epoch 46/50
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0486 - val_loss: 0.0528
# Epoch 47/50
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0404 - val_loss: 0.0097
# Epoch 48/50
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0459 - val_loss: 0.0099
# Epoch 49/50
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0373 - val_loss: 0.0200
# Epoch 50/50
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0316 - val_loss: 0.0617
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step
# Test RMSE: 0.03534241684449219

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np

plt.figure(figsize=(15, 10))

plt.subplot(2, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()

plt.subplot(2, 2, 2)
plt.plot(y_test_orig, 'b-', label='True', linewidth=2)
plt.plot(y_pred_orig, 'r--', label='Predicted', linewidth=2)
plt.title('True vs Predicted')
plt.ylabel('Close Price')
plt.legend()

plt.subplot(2, 2, 3)
errors = y_test_orig.flatten() - y_pred_orig.flatten()
plt.hist(errors, bins=30, alpha=0.7, edgecolor='black')
plt.axvline(x=0, color='r', linestyle='--')
plt.title('Error Distribution')
plt.xlabel('Prediction Error')

plt.subplot(2, 2, 4)
plt.scatter(y_test_orig, y_pred_orig, alpha=0.6)
max_val = max(np.max(y_test_orig), np.max(y_pred_orig))
min_val = min(np.min(y_test_orig), np.min(y_pred_orig))
plt.plot([min_val, max_val], [min_val, max_val], 'k--')
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.title('Scatter Plot')

plt.tight_layout()
plt.show()

rmse = np.sqrt(mean_squared_error(y_test_orig, y_pred_orig))
mae = mean_absolute_error(y_test_orig, y_pred_orig)
r2 = r2_score(y_test_orig, y_pred_orig)
mape = np.mean(np.abs(errors / y_test_orig.flatten())) * 100

direction_true = np.diff(y_test_orig.flatten())
direction_pred = np.diff(y_pred_orig.flatten())
direction_accuracy = np.mean((direction_true * direction_pred) > 0) * 100 if len(direction_true) > 0 else 0

print("=" * 50)
print("MODEL PERFORMANCE METRICS")
print("=" * 50)
print(f"RMSE: {rmse:.6f}")
print(f"MAE: {mae:.6f}")
print(f"R²: {r2:.4f}")
print(f"MAPE: {mape:.2f}%")
print(f"Direction Accuracy: {direction_accuracy:.2f}%")
print(f"Max Error: {np.max(np.abs(errors)):.6f}")
print(f"Mean Error: {np.mean(errors):.6f}")
print("=" * 50)
# Out:
# ==================================================
# MODEL PERFORMANCE METRICS
# ==================================================
# RMSE: 0.035342
# MAE: 0.028412
# R²: 0.6011
# MAPE: 9.31%
# Direction Accuracy: 52.72%
# Max Error: 0.086270
# Mean Error: 0.027396
# ==================================================
